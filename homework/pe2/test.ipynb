# %%
import numpy as np
from scipy.sparse import lil_matrix
from mesh_ops import MeshOps
import matplotlib


import matplotlib.pyplot as plt

# %%
mesh = MeshOps("./mesh/unitSquare1.msh")

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

x = mesh.points[:, 0]
y = mesh.points[:, 1]
ax.plot_trisurf(x, y, np.ones_like(x), triangles=mesh.triangles)
